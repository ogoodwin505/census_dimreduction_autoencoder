# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
import os
import numpy as np
import json

# %%
# --- Utility Functions ---

def compute_errors(original, reconstructed):
    """Compute RMSE and NMSE between original and reconstructed data."""
    error = original - reconstructed
    rmse = np.sqrt(np.mean(error ** 2))
    nmse = ((error ** 2).mean(axis=1) / (original ** 2).mean(axis=1)).mean()
    return rmse, nmse

def load_reconstructed_data(file_path, index_col="ID"):
    """Load reconstructed data from a CSV file."""
    return pd.read_csv(file_path, index_col=index_col)

# --- Error Caching ---

def save_errors(errors, filepath):
    with open(filepath, "w") as f:
        json.dump(errors, f)

def load_errors(filepath):
    with open(filepath, "r") as f:
        return json.load(f)
    
# --- Processing Functions ---

def process_reconstruction(label, file_pattern, bottleneck_sizes, original_data, index_col="ID", inverse_transform=None):
    """Process reconstruction for autoencoder-based methods."""
    metrics = {"rmse": [], "nmse": []}
    #inverse transfrom the data if needed
    if inverse_transform is not None:
        original_data = inverse_transform(original_data)
    for n in tqdm(bottleneck_sizes, desc=f"Processing {label}"):
        reconstructed = load_reconstructed_data(file_pattern.format(n=n), index_col=index_col)
        if inverse_transform is not None:
            reconstructed = inverse_transform(reconstructed)
        # Compute errors
        rmse, nmse = compute_errors(original_data, reconstructed)
        print(f"{label} - {n} components: RMSE = {rmse:.2f}, NMSE = {nmse:.2f}")
        metrics["rmse"].append(rmse)
        metrics["nmse"].append(nmse)
    return metrics

def process_all_methods(original_data, data_path, working_dir, bottleneck_sizes, force_recompute=False):
    cache_path = f"{working_dir}/errors_cache.json"
    if os.path.exists(cache_path) and not force_recompute:
        print(f"Loading cached errors from {cache_path}")
        return load_errors(cache_path)

    errors = {}
    errors["PCA"] = process_reconstruction("PCA", data_path + "PCA/{n}_components.csv", bottleneck_sizes, original_data, index_col="OA")
    errors["Autoencoder"] = process_reconstruction("Autoencoder", f"{working_dir}/census_geodemo__bottleneck_{{n}}_v1__reconstructed_outputs.csv", bottleneck_sizes, original_data, index_col="ID")
    errors["Autoencoder (Sparse)"] = process_reconstruction("Autoencoder (Sparse)", f"{working_dir}/census_geodemo_sparse__bottleneck_{{n}}_v1__reconstructed_outputs.csv", bottleneck_sizes, original_data, index_col="ID")
    errors["Autoencoder (Mul)"] = process_reconstruction("Autoencoder (Mul)", f"../AE_outputs/engcensus_all/250epoch_scan_mul/census_geodemo__bottleneck_{{n}}_v1__reconstructed_outputs.csv", bottleneck_sizes, original_data, index_col="ID")
    save_errors(errors, cache_path)
    return errors

# --- Plotting ---

def plot_errors(errors, bottleneck_sizes, metric, ylabel, title):
    """Plot errors for different reconstruction methods."""
    colors = ["seagreen", "sandybrown", "#E15759", "#76B7B2", "#59A14F", "#EDC949"]
    plt.figure(figsize=(10, 8))

    for i, (label, data) in enumerate(errors.items()):
        if label =="Autoencoder (Sparse)":
            continue
        if label =="Autoencoder (Mul)":
            continue
        plt.plot(
            bottleneck_sizes, np.array(data[metric])*100,  # Convert to percentage for RMSE
            marker='o', markersize=10, linewidth=3.5,
            label=label, color=colors[i % len(colors)]
        )

    plt.xlabel("Dimension of Latent Space", fontsize=18)
    plt.ylabel(ylabel, fontsize=18)
    plt.title(title, fontsize=18)
    plt.legend(fontsize=18, frameon=False)
    plt.grid(True, linestyle="--", alpha=0.7)
    plt.show()


# --- Configuration ---

bottleneck_sizes = [2, 4, 8, 16, 32, 64, 100, 128]

# --- Load Data Once ---

df_scaled = pd.read_parquet("../data/census_data/engcensus_cleaned_scaled.parquet")
df_scaled.set_index(df_scaled.columns[0], inplace=True)

df_zscores = pd.read_parquet("../data/census_data/engcensus_cleaned_zstandardized.parquet")
df_zscores.set_index(df_zscores.columns[0], inplace=True)

# --- Process All ---

nonzscore_path = "../AE_outputs/engcensus_all/"
nonzscore_working_dir = nonzscore_path + "250epoch_scan_lin"

zscore_path = "../AE_outputs/engcensus_all_zstandardized/"
zscore_working_dir = zscore_path + "250epoch_scan_lin"

errors_nonzscore = process_all_methods(df_scaled, nonzscore_path, nonzscore_working_dir, bottleneck_sizes,force_recompute=True)
# errors_zscore = process_all_methods(df_zscores, zscore_path, zscore_working_dir, bottleneck_sizes,force_recompute=True)

# --- Example Plot Calls ---

plot_errors(errors_nonzscore, bottleneck_sizes, "rmse", "RMSE (%)", "RMSE vs. # of Dimensions")
plot_errors(errors_nonzscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions")
# plot_errors(errors_zscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions (Z-Score)")
# Out:
# Processing PCA:  12%|█▎        | 1/8 [00:12<01:27, 12.49s/it]
# PCA - 2 components: RMSE = 0.05, NMSE = 0.04
# Processing PCA:  25%|██▌       | 2/8 [00:22<01:05, 10.99s/it]
# PCA - 4 components: RMSE = 0.05, NMSE = 0.03
# Processing PCA:  38%|███▊      | 3/8 [00:31<00:51, 10.28s/it]
# PCA - 8 components: RMSE = 0.04, NMSE = 0.02
# Processing PCA:  50%|█████     | 4/8 [00:41<00:40, 10.12s/it]
# PCA - 16 components: RMSE = 0.03, NMSE = 0.01
# Processing PCA:  62%|██████▎   | 5/8 [00:51<00:30, 10.08s/it]
# PCA - 32 components: RMSE = 0.02, NMSE = 0.01
# Processing PCA:  75%|███████▌  | 6/8 [01:01<00:20, 10.02s/it]
# PCA - 64 components: RMSE = 0.01, NMSE = 0.00
# Processing PCA:  88%|████████▊ | 7/8 [01:11<00:09,  9.93s/it]
# PCA - 100 components: RMSE = 0.01, NMSE = 0.00
# Processing PCA: 100%|██████████| 8/8 [01:20<00:00, 10.07s/it]
# PCA - 128 components: RMSE = 0.01, NMSE = 0.00
# Processing Autoencoder:  12%|█▎        | 1/8 [00:07<00:52,  7.46s/it]
# ...

# %%
def process_reconstruction(label, file_pattern, bottleneck_sizes, original_data, index_col="ID", inverse_transform=None):
    """Process reconstruction for autoencoder-based methods."""
    metrics = {"rmse": [], "nmse": []}
    #inverse transfrom the data if needed
    for n in tqdm(bottleneck_sizes, desc=f"Processing {label}"):
        reconstructed = load_reconstructed_data(file_pattern.format(n=n), index_col=index_col)
        # Compute errors
        rmse, nmse = compute_errors(original_data, reconstructed)
        print(f"{label} - {n} components: RMSE = {rmse:.2f}, NMSE = {nmse:.2f}")
        metrics["rmse"].append(rmse)
        metrics["nmse"].append(nmse)
    return metrics

def compute_errors(original, reconstructed):
    """Compute RMSE and NMSE between original and reconstructed data."""
    error = original - reconstructed
    print(np.mean(error ** 2))
    rmse = np.sqrt(np.mean(error ** 2))
    nmse = np.mean((error ** 2) / (original ** 2 + 1e-8))
    return rmse, nmse

# %%
# --- Load Data Once ---

df_scaled = pd.read_parquet("../data/census_data/engcensus_cleaned_scaled.parquet")
df_scaled.set_index(df_scaled.columns[0], inplace=True)

nonzscore_path = "../AE_outputs/engcensus_all/"
nonzscore_working_dir = nonzscore_path + "250epoch_scan_lin"
bottleneck_sizes = [ 100]

pca_err_here = process_reconstruction("PCA", nonzscore_path + "PCA/{n}_components.csv", bottleneck_sizes, df_scaled, index_col="OA")
# Out:
# Processing PCA:   0%|          | 0/1 [00:00<?, ?it/s]
#            ts0010002  ts0010003  ts0020002  ts0020003  ts0020004  ts0020005  \
# OA
# E00000001   0.993011   0.006989   0.235830   0.559517   0.549911   0.541063
# E00000003   0.992924   0.007076   0.323023   0.590641   0.581964   0.573738
# E00000005   0.990303   0.009697   0.424736   0.402493   0.393896   0.385279
# E00000007   1.005764  -0.005764   0.712865   0.212103   0.203641   0.195061
# E00000010   0.994971   0.005029   0.740703   0.166902   0.160800   0.154619
# ...              ...        ...        ...        ...        ...        ...
# W00010693   0.124773   0.875227   0.951817   0.002040   0.004142   0.005089
# W00010694   0.997384   0.002616   0.295154   0.532666   0.531009   0.528719
# W00010695   0.999679   0.000321   0.265115   0.564491   0.562377   0.559805
# W00010696   0.996209   0.003791   0.338041   0.568946   0.566370   0.560984
# W00010697   0.997250   0.002750   0.519207   0.323098   0.321366   0.317446
# ...

# %%
pca_path = f"../AE_outputs/engcensus_all/PCA/100_components.csv"
pca_reco = pd.read_csv(pca_path, index_col=0)
cleaned_data_path = "../data/census_data/engcensus_cleaned_scaled.parquet"
data = pd.read_parquet(cleaned_data_path)
pca_err = np.sqrt(np.mean((data.set_index("OA") - pca_reco) ** 2, axis=1)).reset_index()
print(np.mean((data.set_index("OA") - pca_reco) ** 2, axis=1))
print(pca_err)
pca_err[0].mean()
# Out:
#            ts0010002  ts0010003  ts0020002  ts0020003  ts0020004  ts0020005  \
# OA
# E00000001   0.993011   0.006989   0.235830   0.559517   0.549911   0.541063
# E00000003   0.992924   0.007076   0.323023   0.590641   0.581964   0.573738
# E00000005   0.990303   0.009697   0.424736   0.402493   0.393896   0.385279
# E00000007   1.005764  -0.005764   0.712865   0.212103   0.203641   0.195061
# E00000010   0.994971   0.005029   0.740703   0.166902   0.160800   0.154619
# ...              ...        ...        ...        ...        ...        ...
# W00010693   0.124773   0.875227   0.951817   0.002040   0.004142   0.005089
# W00010694   0.997384   0.002616   0.295154   0.532666   0.531009   0.528719
# W00010695   0.999679   0.000321   0.265115   0.564491   0.562377   0.559805
# W00010696   0.996209   0.003791   0.338041   0.568946   0.566370   0.560984
# W00010697   0.997250   0.002750   0.519207   0.323098   0.321366   0.317446
#
# ...

# %%
pca_err[0].mean()
# Out:
# np.float64(0.008939997629959617)

# %%
# Out:
# Index(['OA', 0], dtype='object')

# %%
# Out:
# np.float64(0.008939997629959617)

# %%
pca_err = np.sqrt(np.mean((data.set_index("OA") - pca_reco) ** 2, axis=1)).reset_index()*100

# %%
  0.008259*100,  0.00943*100
# Out:
# (0.8259000000000001, 0.943)

# %%
# --- Configuration ---

bottleneck_sizes = [2, 4, 8, 16, 32, 64, 100, 128]

# --- Load Data Once ---

df_scaled = pd.read_parquet("../data/census_data/engcensus_cleaned_scaled.parquet")
df_scaled.set_index(df_scaled.columns[0], inplace=True)

df_zscores = pd.read_parquet("../data/census_data/engcensus_cleaned_zstandardized.parquet")
df_zscores.set_index(df_zscores.columns[0], inplace=True)

# --- Process All ---

nonzscore_path = "../AE_outputs/engcensus_all/"
nonzscore_working_dir = nonzscore_path + "250epoch_scan_lin"

zscore_path = "../AE_outputs/engcensus_all_zstandardized/"
zscore_working_dir = zscore_path + "250epoch_scan_lin"

errors_nonzscore = process_all_methods(df_scaled, nonzscore_path, nonzscore_working_dir, bottleneck_sizes,force_recompute=True)
errors_zscore = process_all_methods(df_zscores, zscore_path, zscore_working_dir, bottleneck_sizes,force_recompute=True)

# --- Example Plot Calls ---

plot_errors(errors_nonzscore, bottleneck_sizes, "rmse", "RMSE (%)", "RMSE vs. # of Dimensions")
plot_errors(errors_nonzscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions")
plot_errors(errors_zscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions (Z-Score)")

# %%
errors_nonzscore
# Out:
# {'PCA': {'rmse': [np.float64(0.05446887949251834),
#    np.float64(0.045662286970780695),
#    np.float64(0.03722443382323289),
#    np.float64(0.02815034696850449),
#    np.float64(0.020354070661935397),
#    np.float64(0.013590253996820385),
#    np.float64(0.009435919954292934),
#    np.float64(0.007234307829166962)],
#   'nmse': [np.float64(0.044798166390588395),
#    np.float64(0.03143932876432992),
#    np.float64(0.02096974575496244),
#    np.float64(0.01201900652525479),
#    np.float64(0.006282816374017433),
#    np.float64(0.0028147805442875883),
#    np.float64(0.0013665100022014279),
#    np.float64(0.0008060676122248776)]},
#  'Autoencoder': {'rmse': [np.float64(0.04297332784318856),
#    np.float64(0.035379636646853674),
#    np.float64(0.02771134193367387),
#    np.float64(0.02197888167970857),
#    np.float64(0.016485255123048013),
#    np.float64(0.011617022793519909),
#    np.float64(0.009276990130827051),
#    np.float64(0.008105782709455337)],
# ...

# %%
# --- Example Plot Calls ---

plot_errors(errors_nonzscore, bottleneck_sizes, "rmse", "RMSE", "RMSE vs. # of Dimensions")
plot_errors(errors_nonzscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions")
plot_errors(errors_zscore, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions (Z-Score)")

# %%
def process_all_methods_inverse(original_data, data_path, working_dir, bottleneck_sizes, inverse_transform ,force_recompute=False):
    cache_path = f"{working_dir}/errors_cache_inverse.json"
    if os.path.exists(cache_path) and not force_recompute:
        print(f"Loading cached errors from {cache_path}")
        return load_errors(cache_path)
    errors = {}
    errors["PCA"] = process_reconstruction("PCA", data_path + "PCA/{n}_components.csv",
                                            bottleneck_sizes,
                                              original_data,
                                                index_col="OA", inverse_transform=inverse_transform)
    errors["Autoencoder"] = process_reconstruction("Autoencoder",
                                                    f"{working_dir}/census_geodemo__bottleneck_{{n}}_v1__reconstructed_outputs.csv",
                                                      bottleneck_sizes, original_data, index_col="ID", inverse_transform=inverse_transform)
    errors["Autoencoder (Sparse)"] = process_reconstruction("Autoencoder (Sparse)", f"{working_dir}/census_geodemo_sparse__bottleneck_{{n}}_v1__reconstructed_outputs.csv",
                                                             bottleneck_sizes,
                                                               original_data, index_col="ID", inverse_transform=inverse_transform)

    save_errors(errors, cache_path)
    return errors

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
    # Fit the scaler to the original data
scaler.fit(df_scaled)
inverse_transform = scaler.inverse_transform
 
errors_zscore_inv = process_all_methods_inverse(df_zscores, zscore_path, zscore_working_dir, bottleneck_sizes, inverse_transform=inverse_transform)

# --- Example Plot Calls ---

plot_errors(errors_zscore_inv, bottleneck_sizes, "nmse", "NMSE", "NMSE vs. # of Dimensions (Z-Score inverse)")
# Out:
# Processing PCA:  12%|█▎        | 1/8 [00:11<01:22, 11.83s/it]
# PCA - 2 components: RMSE = 0.06, NMSE = 0.05
# Processing PCA:  25%|██▌       | 2/8 [00:23<01:11, 12.00s/it]
# PCA - 4 components: RMSE = 0.05, NMSE = 0.03
# Processing PCA:  38%|███▊      | 3/8 [00:40<01:09, 13.93s/it]
# PCA - 8 components: RMSE = 0.04, NMSE = 0.03
# Processing PCA:  50%|█████     | 4/8 [00:54<00:55, 13.92s/it]
# PCA - 16 components: RMSE = 0.04, NMSE = 0.02
# Processing PCA:  62%|██████▎   | 5/8 [01:09<00:43, 14.48s/it]
# PCA - 32 components: RMSE = 0.03, NMSE = 0.01
# Processing PCA:  75%|███████▌  | 6/8 [01:23<00:28, 14.20s/it]
# PCA - 64 components: RMSE = 0.03, NMSE = 0.01
# Processing PCA:  88%|████████▊ | 7/8 [01:37<00:14, 14.35s/it]
# PCA - 100 components: RMSE = 0.02, NMSE = 0.01
# Processing PCA: 100%|██████████| 8/8 [01:52<00:00, 14.09s/it]
# PCA - 128 components: RMSE = 0.02, NMSE = 0.01
# Processing Autoencoder:  12%|█▎        | 1/8 [00:09<01:06,  9.55s/it]
# ...
